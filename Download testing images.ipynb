# %%
##Download some images
import urllib.request as request

#no entry
img = request.urlretrieve("data:image/jpeg;base64,...","testing_images/no_entry.jpg")
#yield
img = request.urlretrieve("data:image/png;base64,...","testing_images/yield.png")  
#stop sign
img = request.urlretrieve("data:image/png;base64,...", "testing_images/stop_sign.png")
#road work
img = request.urlretrieve("data:image/png;base64,...","testing_images/road_work.png")
#60 km
img = request.urlretrieve("data:image/png;base64,...","testing_images/60_km.png")
#turn_left
img = request.urlretrieve("https://encrypted-tbn1.gstatic.com/images?q=tbn:ANd9GcQsoMyeRRyS-vY8cGnLV6poySbfgoVN1rVlZHUqdf2wFxHuevUdmA", "testing_images/turn_left.jpg")
